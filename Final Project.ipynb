# %% [markdown]
# # EDA

# %%
# Import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
# Import data

df = pd.read_csv('Customer-Churn-Records.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5788\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber            1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId           0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore          0.005840    0.005308     1.000000 -0.003965  0.000842
# Age                  0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure              -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance             -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts        0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard            0.000599   -0.014025    -0.005458 -0.011721  0.022583
# ...

# %%
corr = df.corr().round(2)
plt.figure(figsize = (25,20))
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5788\527794839.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr().round(2)
# <Axes: >

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
df2 = df.drop(['RowNumber', 'CustomerId', 'Surname', 'Geography'], axis='columns')

# %%
df2 = df2.rename(columns={'EstimatedSalary': 'Salary', 'Tenure': 'YearsWithBank'})

# %%
df2['JoinAge'] = df2['Age'] - df2['YearsWithBank']

# %%
df2.head()
# Out:
#    CreditScore  Gender  Age  YearsWithBank    Balance  NumOfProducts  \
# 0          619  Female   42              2       0.00              1
# 1          608  Female   41              1   83807.86              1
# 2          502  Female   42              8  159660.80              3
# 3          699  Female   39              1       0.00              2
# 4          850  Female   43              2  125510.82              1
#
#    HasCrCard  IsActiveMember     Salary  Exited  Complain  Satisfaction Score  \
# 0          1               1  101348.88       1         1                   2
# 1          0               1  112542.58       0         1                   3
# 2          1               0  113931.57       1         1                   3
# 3          0               0   93826.63       0         0                   5
# 4          1               1   79084.10       0         0                   5
#
#   Card Type  Point Earned  JoinAge
# 0   DIAMOND           464       40
# ...

# %%
df2.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5788\1778878097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                     CreditScore       Age  YearsWithBank   Balance  \
# CreditScore            1.000000 -0.003965       0.000842  0.006268
# Age                   -0.003965  1.000000      -0.009997  0.028308
# YearsWithBank          0.000842 -0.009997       1.000000 -0.012254
# Balance                0.006268  0.028308      -0.012254  1.000000
# NumOfProducts          0.012238 -0.030680       0.013444 -0.304180
# HasCrCard             -0.005458 -0.011721       0.022583 -0.014858
# IsActiveMember         0.025651  0.085472      -0.028362 -0.010084
# Salary                -0.001384 -0.007201       0.007784  0.012797
# Exited                -0.026771  0.285296      -0.013656  0.118577
# ...

# %%
df2.corr().round(2)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5788\2559797484.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr().round(2)
#                     CreditScore   Age  YearsWithBank  Balance  NumOfProducts  \
# CreditScore                1.00 -0.00           0.00     0.01           0.01
# Age                       -0.00  1.00          -0.01     0.03          -0.03
# YearsWithBank              0.00 -0.01           1.00    -0.01           0.01
# Balance                    0.01  0.03          -0.01     1.00          -0.30
# NumOfProducts              0.01 -0.03           0.01    -0.30           1.00
# HasCrCard                 -0.01 -0.01           0.02    -0.01           0.00
# IsActiveMember             0.03  0.09          -0.03    -0.01           0.01
# ...

# %%
df2_corr = df2.corr().round(2)
plt.figure(figsize = (25,20))
sns.heatmap(df2_corr, annot = True, cmap = 'coolwarm')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5788\2216774780.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2_corr = df2.corr().round(2)
# <Axes: >

# %%
#Don't know when the complaint was logged (before or after exiting), so we will remove it for this reason and to prevent over reliance on theis variable

# %%
df2.drop('Complain', axis=1, inplace=True)

# %%
df2.hist(bins=50, figsize=(20,20));

# %%
plt.figure(figsize = (20, 25))


plt.subplot(5, 2, 1)
plt.gca().set_title('Variable Gender')
sns.countplot(x = 'Gender', palette = 'Set2', data = df2)

plt.subplot(5, 2, 2)
plt.gca().set_title('Variable Tenure')
sns.countplot(x = 'YearsWithBank', palette = 'Set2', data = df2)

plt.subplot(5, 2, 3)
plt.gca().set_title('Variable NumOfProducts')
sns.countplot(x = 'NumOfProducts', palette = 'Set2', data = df2)

plt.subplot(5, 2, 4)
plt.gca().set_title('Variable HasCrCard')
sns.countplot(x = 'HasCrCard', palette = 'Set2', data = df2)

plt.subplot(5, 2, 5)
plt.gca().set_title('Variable IsActiveMember')
sns.countplot(x = 'IsActiveMember', palette = 'Set2', data = df2)

plt.subplot(5, 2, 6)
plt.gca().set_title('Variable Exited')
sns.countplot(x = 'Exited', palette = 'Set2', data = df2)

plt.subplot(5, 2, 7)
plt.gca().set_title('Variable Complain')
sns.countplot(x = 'Complain', palette = 'Set2', data = df)

plt.subplot(5, 2, 8)
plt.gca().set_title('Variable JoinAge')
sns.countplot(x = 'JoinAge', palette = 'Set2', data = df2)
# Out:
# <Axes: title={'center': 'Variable JoinAge'}, xlabel='JoinAge', ylabel='count'>

# %%
plt.figure(figsize = (20, 25))

plt.subplot
plt.gca().set_title('Variable JoinAge')
sns.countplot(x = 'JoinAge', palette = 'Set2', data = df2)
# Out:
# <Axes: title={'center': 'Variable JoinAge'}, xlabel='JoinAge', ylabel='count'>

# %%
pd.plotting.scatter_matrix(df2, figsize = (20,20));

# %%
df2.to_csv("df2")

# %%
df2.to_excel('df2.xlsx')

# %%
df2
# Out:
#       CreditScore  Gender  Age  YearsWithBank    Balance  NumOfProducts  \
# 0             619  Female   42              2       0.00              1
# 1             608  Female   41              1   83807.86              1
# 2             502  Female   42              8  159660.80              3
# 3             699  Female   39              1       0.00              2
# 4             850  Female   43              2  125510.82              1
# ...           ...     ...  ...            ...        ...            ...
# 9995          771    Male   39              5       0.00              2
# 9996          516    Male   35             10   57369.61              1
# 9997          709  Female   36              7       0.00              1
# 9998          772    Male   42              3   75075.31              2
# 9999          792  Female   28              4  130142.79              1
#
#       HasCrCard  IsActiveMember     Salary  Exited  Satisfaction Score  \
# ...

# %%
df3 = df2[['Gender','NumOfProducts','Exited']]

# %%
df3[df3['Gender'] == "Male"]
# Out:
#      Gender  NumOfProducts  Exited
# 5      Male              2       1
# 6      Male              2       0
# 8      Male              2       0
# 9      Male              1       0
# 10     Male              2       0
# ...     ...            ...     ...
# 9992   Male              1       0
# 9993   Male              1       0
# 9995   Male              2       0
# 9996   Male              1       0
# 9998   Male              2       1
#
# [5457 rows x 3 columns]

# %%
filter1 = df3["Gender"].isin(["Female"])

# %%
filter1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9995    False
# 9996    False
# 9997     True
# 9998    False
# 9999     True
# Name: Gender, Length: 10000, dtype: bool

# %%
df3.pivot_table(index="NumOfProducts",columns="Gender", aggfunc="size")
# Out:
# Gender         Female  Male
# NumOfProducts
# 1                2296  2788
# 2                2060  2530
# 3                 149   117
# 4                  38    22

# %%
df2.groupby(['Gender', 'NumOfProducts'])['Gender','NumOfProducts','Exited'].sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5788\3129728316.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2.groupby(['Gender', 'NumOfProducts'])['Gender','NumOfProducts','Exited'].sum()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5788\3129728316.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.groupby(['Gender', 'NumOfProducts'])['Gender','NumOfProducts','Exited'].sum()
#                       NumOfProducts  Exited
# Gender NumOfProducts
# Female 1                       2296     762
#        2                       4120     210
#        3                        447     129
#        4                        152      38
# Male   1                       2788     647
# ...
